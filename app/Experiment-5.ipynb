# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from sklearn.neighbors import NearestNeighbors

# %%
#reading the data
data = pd.read_csv('data/all_data.csv', on_bad_lines='skip')
display(data)
# Out:
#              Kunde   customname  customform                            name  \
# 0      abinventech      form876         876                Kundereklamation
# 1      abinventech      form876         876                Kundereklamation
# 2      abinventech      form876         876                Kundereklamation
# 3      abinventech      form876         876                Kundereklamation
# 4      abinventech      form876         876                Kundereklamation
# ...            ...          ...         ...                             ...
# 10331          ipw  form1927875     1927875  Azure - Udløb af client secret
# 10332          ipw  form1329139     1329139                      Leverancer
# 10333          ipw  form1329139     1329139                      Leverancer
# 10334          ipw  form1329139     1329139                      Leverancer
# 10335          ipw  form1329139     1329139                      Leverancer
#
#        fieldobjectid  fieldparentid    fieldparenttype elementtype  \
# 0                877          878.0  customformelement       field
# 1                878            NaN         customform       block
# 2                879          878.0  customformelement       field
# 3                880          878.0  customformelement       field
# 4                881          878.0  customformelement       field
# ...              ...            ...                ...         ...
# 10331        2610308      2592044.0  customformelement     special
# 10332        2612534            NaN         customform       block
# 10333        2612540      1361554.0  customformelement     special
# 10334        2612546      1361554.0  customformelement     special
# 10335        2612585      1361554.0  customformelement       field
#
#          fieldtype        blocktype  specialtype fieldrelation  \
# 0       listselect              NaN          NaN      form2488
# 1              NaN  layout_fieldset          NaN           NaN
# 2           string              NaN          NaN           NaN
# 3           string              NaN          NaN           NaN
# 4           string              NaN          NaN           NaN
# ...            ...              ...          ...           ...
# 10331          NaN              NaN    createdby           NaN
# 10332          NaN  layout_fieldset          NaN           NaN
# 10333          NaN              NaN  layout_text           NaN
# 10334          NaN              NaN  layout_text           NaN
# 10335  radiobutton              NaN          NaN           NaN
#
#                                               fieldlabel language
# 0                                             Vælg kunde       DA
# 1                                       Kundeoplysninger       DA
# 2                                               Gadenavn       DA
# 3                                                 Postnr       DA
# 4                                                     By       DA
# ...                                                  ...      ...
# 10331                            Ansvarlig for opsætning       DA
# 10332                                      UDGÅET felter       DA
# 10333     Installationen oprettes på domænet xxxx.ipw.dk       DA
# 10334  Installationen oprettes på domænet <b>xxxx.ipw...       DA
# 10335               Kunden ønsker at anvende eget domæne       DA
#
# [10336 rows x 14 columns]

# %% [markdown]
# # Data Processing
#
#
# ## Field Type Handling
#
# 1. Ensure that the correct field type values are taken from the data source (special).
# 2. Write these values into their corresponding `fieldtype` columns.
#
# ## Grouping Forms
#
# - Group the forms based on their **ID** and **Name**.
# - This allows for better organization and easier access to related data.
#
# ## Mapping Field Types and Labels
#
# - After grouping, map each **fieldtype** with its corresponding **field label**.
# - This mapping ensures that each field is appropriately identified and categorized for further use.

# %%
# Remove all elements of type block.(maybe late include it)
indices_to_drop = data[data['elementtype'] == 'block'].index

# Drop those indices
data = data.drop(indices_to_drop)

# If the element is special the actual fieldtype is in specialtype

data['isspecial'] = data['elementtype'].apply(lambda x: 1 if x == 'special' else 0)

for index, row in data.iterrows():
    if row['isspecial'] == 1:
        if pd.notnull(row['fieldtype']):  # Check if 'fieldtype' is already filled
            print(f"Row {index}: 'fieldtype' already has a value before assigning 'specialtype'")
        else:
            # If 'fieldtype' is empty, assign the value from 'specialtype'
            data.at[index, 'fieldtype'] = row['specialtype']

#Drop non-relevant columns.
data = data.drop(columns=['Kunde','isspecial','elementtype', 'customname','fieldobjectid','fieldparentid','fieldparenttype','blocktype','fieldrelation','language','specialtype'])

#Lets group the data by customform (id) and include name and mape the structure.
result = data.groupby(['customform', 'name']).agg({
    'fieldtype': lambda x: list(x),  # Keep all field types as a list
    'fieldlabel': lambda x: list(x)  # keep all field labels as a list
}).reset_index()

display(result)
# Out:
#      customform                                  name  \
# 0           770                     Projektportefølje
# 1           775                         Projektområde
# 2           876                                Claims
# 3           876                      Kundereklamation
# 4           876                           Reklamation
# ..          ...                                   ...
# 854     2584010                       Formularkatalog
# 855     2584018            Formularkatalog - Kategori
# 856     2584251  Formularkatalog - Øvrige vurderinger
# 857     2584255     Formularkatalog - Vurderingsskala
# 858     2597892                          Vidensdeling
#
#                                              fieldtype  \
# 0    [autonum, created, createdby, relation, string...
# 1                                             [string]
# 2    [userrelation, text, relation, text, createdby...
# 3    [listselect, string, string, string, string, s...
# 4    [listselect, string, string, userrelation, rel...
# ..                                                 ...
# 854  [createdby, created, layout_linebreak, changed...
# 855                                           [string]
# 856               [text, userrelation, relation, text]
# 857                                          [integer]
# 858                                     [string, text]
#
#                                             fieldlabel
# 0    [Projekt nr., Oprettet den, Oprettet af, Proje...
# 1                                              [Tekst]
# 2    [Processor, Description of claim, Complaint ca...
# 3    [Vælg kunde, Gadenavn, Postnr, By, Telefonnumm...
# 4    [Vælg kunde, E-mail, Kontaktperson, Behandles ...
# ..                                                 ...
# 854  [Oprettet af, Oprettet, Blank linje, Seneste æ...
# 855                                         [Kategori]
# 856  [Hvad gør formularen god?, Vurderet af, Vurder...
# 857                                        [Vurdering]
# 858                      [Emne, Uddybende beskrivelse]
#
# [859 rows x 4 columns]

# %% [markdown]
# # Embeddings
#
# In this section, we focus on converting form data into sentence embeddings and storing them.
#
# ## Converting Form to Sentence
#
# 1. Convert each form into a sentence that includes the following details:
#    - **Form Name**
#    - **Field Type**
#    - **Field Label**
# ## Creating Embeddings
#
# 2. After generating the sentence, create an embedding for each one. This embedding represents the form as a vector for easier comparison and analysis.
#
# 3. Store these embeddings in a new column called `['combined_embedding']` for each form.

# %%
 #Combine the text into a single list for Word2Vec
all_texts = [result['name'].tolist()] + result['fieldtype'].tolist() + result['fieldlabel'].tolist()

# Flatten the list of lists to a single list of strings
all_texts = [str(item) for sublist in all_texts for item in sublist]

# Tokenize the text into lists of words
tokenized_texts = [text.split() for text in all_texts]

# Train Word2Vec model
model = Word2Vec(sentences=tokenized_texts, vector_size=100, window=5, min_count=1, workers=4)

# Create Embeddings
def get_embedding(text):
    # If the input is a list, join it to form a single string
    if isinstance(text, list):
        # Convert all elements to string and filter out None or NaN values
        text = ' '.join(str(item) for item in text if pd.notna(item))
    
    # Handle case where text might still be empty after filtering
    if not text:
        return [0] * model.vector_size

    # Tokenize the text
    words = text.split()
    word_vectors = [model.wv[word] for word in words if word in model.wv]
    
    if len(word_vectors) == 0:  # In case no words are in the model
        return [0] * model.vector_size
    
    # Average the word vectors
    return np.mean(word_vectors, axis=0)

def combine_fields(row):
    # Combine the name with all elements from fieldtype and fieldlabel arrays
    fields = [row['name']] + list(row['fieldtype']) + list(row['fieldlabel'])
    
    # Join all values into a single string, ensuring they're all converted to strings
    return ' '.join(str(item) for item in fields if pd.notna(item))

# Apply the function to create a combined text column
result['combined_text'] = result.apply(combine_fields, axis=1)

# Generate embeddings for the combined text
result['combined_embedding'] = result['combined_text'].apply(get_embedding)
# Display the results
display(result[['name', 'fieldtype', 'fieldlabel','combined_embedding']])
# Out:
#                                      name  \
# 0                       Projektportefølje
# 1                           Projektområde
# 2                                  Claims
# 3                        Kundereklamation
# 4                             Reklamation
# ..                                    ...
# 854                       Formularkatalog
# 855            Formularkatalog - Kategori
# 856  Formularkatalog - Øvrige vurderinger
# 857     Formularkatalog - Vurderingsskala
# 858                          Vidensdeling
#
#                                              fieldtype  \
# 0    [autonum, created, createdby, relation, string...
# 1                                             [string]
# 2    [userrelation, text, relation, text, createdby...
# 3    [listselect, string, string, string, string, s...
# 4    [listselect, string, string, userrelation, rel...
# ..                                                 ...
# 854  [createdby, created, layout_linebreak, changed...
# 855                                           [string]
# 856               [text, userrelation, relation, text]
# 857                                          [integer]
# 858                                     [string, text]
#
#                                             fieldlabel  \
# 0    [Projekt nr., Oprettet den, Oprettet af, Proje...
# 1                                              [Tekst]
# 2    [Processor, Description of claim, Complaint ca...
# 3    [Vælg kunde, Gadenavn, Postnr, By, Telefonnumm...
# 4    [Vælg kunde, E-mail, Kontaktperson, Behandles ...
# ..                                                 ...
# 854  [Oprettet af, Oprettet, Blank linje, Seneste æ...
# 855                                         [Kategori]
# 856  [Hvad gør formularen god?, Vurderet af, Vurder...
# 857                                        [Vurdering]
# 858                      [Emne, Uddybende beskrivelse]
#
#                                     combined_embedding
# 0    [-0.020117719, 0.024822399, 0.008052918, 0.011...
# 1    [0.0011589956, -0.00017239463, 0.0038565947, 0...
# 2    [-0.021911759, 0.027647354, 0.006353144, 0.012...
# 3    [-0.03126676, 0.038801298, 0.01043382, 0.02038...
# 4    [-0.035052627, 0.044346053, 0.01288192, 0.0216...
# ..                                                 ...
# 854  [-0.045399576, 0.05695349, 0.015131215, 0.0266...
# 855  [-0.058864407, 0.07338592, 0.019110123, 0.0345...
# 856  [-0.037632193, 0.04930217, 0.012702091, 0.0197...
# 857  [-0.056975443, 0.07267847, 0.01962966, 0.03325...
# 858  [-0.006579382, 0.0065678866, 0.0017884843, 0.0...
#
# [859 rows x 4 columns]

# %% [markdown]
# # Model Training
#
# we will focus on training a machine learning model using the embeddings created previously.
#
# ## Fitting the Combined Embedding to K-Nearest Neighbors (KNN)
#
# 1. **Fit the `combined_embedding`** data to a K-Nearest Neighbors (KNN) model. This model will allow us to identify the similarity between different forms based on their embeddings.
#
# ## Returning the Nearest Neighbors
#
# 3. Once the model is trained, use it to return the **nearest 5 neighbors** for any given form. This will help in identifying similar forms based on their embeddings.

# %%
knn = NearestNeighbors(n_neighbors=5)  # We want the 5 closest neighbor
knn.fit(np.vstack(result['combined_embedding'].values))
# Out:
# NearestNeighbors()

# %% [markdown]
# # Testing the Model
#
# we will test the K-Nearest Neighbors (KNN) model using a new form and perform the necessary steps to analyze the results.
#
# ## Data Processing for New Form
#
# 1. **Input**: Provide the model with a new form consisting of:
#    - **Form Name**
#    - **3 Fields** (including field types and labels)
#
# 2. **Apply the same data processing** steps as done during training.
#
# ## Finding the Nearest Neighbors
#
# 3. Use the trained KNN model to find the **5 nearest neighbors** of the new form based on the `combined_embedding`.
#
# ## Filtering Common Fields
#
# 4. From the output, **filter out the common fields** between the new form and its nearest neighbors. This will help us focus on the unique aspects of the new form.
#
# ## Printing Uncommon Labels
#
# 5. Finally, print the **uncommon labels** from the nearest neighbors to highlight the differences. This will help us understand what makes the new form unique compared to the others.

# %%
# Example form to predict
new_name = "Sikkerhed"
fieldtypes = ['createdby', 'created', 'responsible']
labels = ['Oprettet af', 'Oprettelsesdato', 'Ansvarlig']

combined_text = ' '.join([new_name] + fieldtypes + labels)
cembedding =get_embedding(combined_text)
cembedding = cembedding.reshape(1, -1)


distances, indices = knn.kneighbors(cembedding)

closest_points = result.iloc[indices[0]]  

# Collect all field labels from the nearest neighbors
all_field_labels = [result.iloc[index]['fieldlabel'] for index in indices[0]]

# Flatten the list of field labels and normalize to lowercase
flattened_labels = [label.lower() for labels in all_field_labels for label in labels]

# Count the occurrences of each normalized field label
from collections import Counter
label_counts = Counter(flattened_labels)

# Separate common and uncommon labels
common_labels = [label for label, count in label_counts.items() if count > 3]
uncommon_labels = [label for label, count in label_counts.items() if count == 1]

print("Common Field Labels (case-insensitive):")
for label in common_labels:
    print(label)

print('-----------------------------------------------------')
print("\nUncommon Field Labels (case-insensitive):")
for label in uncommon_labels:
    print(label)
# Out:
# Common Field Labels (case-insensitive):
# oprettet
# oprettet af
# ansvarlig
# nummer
# evt. relateret afvigelse
# følgende udføres
# deadline
# vælg ansvarlig
# hvad er udført
# udført dato
# verificeret dato
# kommentar
# evt. relateret reklamation
# kundens fejlbeskrivelse
# blank 15px
# beskrivelse af afvigelsen
# blank 20
# send information til
# vælg kunde
# gadenavn
# postnr
# by
# telefonnummer
# e-mail
# kontaktperson
# kundens reference
# behandles af
# handling der førte til reklamationen
# valgt løsning
# omkostning, kr
# årsag til reklamationen
# varenummer
# varenavn
# vedhæft filer
# navn
# reklamation opstået hos
# antal
# enheder
# batchnr
# fejlkode
# fejlkategori
# korrigerende handling(er)
# vælg behandler
# bemærkning
# det har jeg gjort
# afvigelsen skete den
# korrigerende handling
# relateret til audit nr.
# risikovurdering
# er problemet tilstrækkeligt løst?
# bemærkninger
# -----------------------------------------------------
#
# Uncommon Field Labels (case-insensitive):
# løn prod. (kr)
# tegnestuen timer
# løn tegnestuen (kr)
# godkendes af
# godkendelse
# titel
# relateret kundereklamation
# titel på opgave
# relateret til leverandørreklamation
# fra afvigelse
# følgende udføres:
# deadline for udførelse
# ansvarlig for udførelse
# hvad er konkret udført
# tiltag evalueret den:
# kommentar til evaluering
# fra reklamation
# reinstruktion nødvendig
# instruktioner
# ansvarlig for evaluering
# hvem har udført opgaven?
# effekt af korrigerende handling
# deadline for evaluering
# upload dokumentation
# flyt deadline
# begrundelse for ændring af deadline
# ny deadline
# supplerende korrigerende handling
# titel på korrigerende handling
# fra audit
# succeskriterier
# evt. relateret reklamation (parkeret)
# relateret reklamation
# upload filer
# plan for udførsel
# overskrift
# evt. a- eller v- nummer
# supplerende tekniske oplysninger
# korrigerende handlinger
# kategori
# hvem har angivet reklamationen
# holdbarhedsdato
# dato for modtagelse af reklamationen
# produktions afdeling
# kommentar til valgte løsning
# vælg kunde (bruges ikke)
# kundenr
# handling der førte til reklamationen (bruges ikke)
# valgt løsning (bruges ikke)
# omkostning, kr (bruges ikke)
# reklamation opstået hos (bruges ikke)
# varenr
# varenavn (bruges ikke)
# kort beskrivelse af fejlen
# vedhæft filer (pdf. docx. jpeg, png, gif) (anvendes ikke længere)
# ansvarlig for opfølgning
# salgsansvarlig
# egne kommentarer til sagen
# ident / faktura
# identnr
# virksomhed
# leveringsdato
# tekst
# fra dato
# til dato
# garanti
# reklamation
# intern afvigelse
# qhse konklusion
# stadie behandling
# konklusions dato
# risiko for personskade?
# land
# vedhæft filer (pdf. docx. jpeg, png, gif)
# risikovurdering (skjules)
# hvor opstod afvigelsen?
# hvor blev afvigelsen opdaget?
# funktionær timer
# løn funktionær (kr)
# løn produktion (kr)
# husk at gemme efter en korr. handling er oprettet !!
# konverter til forbedringsforslag
# opret forbedringsforslag
# objectid
# evt. relateret forbedringsforslag
# send emails cc til
# tegningsnummer
# konklusion på root cause - udgået
# action her og nu
# afdeling
# beskriv andet
# konklusion på korrigerende handling
# opret root cause - udgået
# root cause? udgået
# begrundelse for ingen root cause udgået
# leverandørnavn
# root cause
# er der behov for at tilknytte leverandør eller serviceleverandør  info?
# vælg serviceleverandør
# serviceleverandør
# vælg leverandør (anvendes når kunde er klar)
# sagsbehandler
# overskrift til afvigelsen
# relateret til audit
# beskriv årsagen til afvigelsen
# produktkategori
# er korrigerende handlinger påkrævet?
# link til evt. dokumentation
# korrigerende handlinger med ansvarlig og deadline oprettes separat i fanebladet her på afvigelsesformularen, eller...
# korrektion
# afvigelseskategori
# hvem skal behandle afvigelsen?
# det har jeg gjort for at stoppe afvigelsen
# vedhæft dokumentation
# konklusion
# send orientering til
# er analyse nødvendig?
# skabelon fiskeben
# 8d rapporter
# 5 x hvorfor
# udfyldte analyser
# cpq - omkostninger ved afvigelsen?
# hvorfor er analyse ikke nødvendig?
# kort beskrivelse/overskrift
# id-nr.:
# benyttes ikke - afvt
# break-even beregning
# metode
# miljø
# måling
# maskiner
# materialer
# mennesker
# husk! der skal oprettes en korrigerende handling før afvigelsen kan lukkes
# guide
# nr
# kort beskrivelse
# uddybning
# testbeskrivelse
# version
# offentlig beskrivelse
# testes af
# offentlig overskrift
# offentlig henvisning (link)
# offentlig kategorisering
# link
# lav dokumentation?
# fremhæv
# test unødvendig?
# darcs patch-tekst
# kommentar vedr dokumentation
# lav ændringslog?
# relevant for konsulenter?
# patchtype
# plenumgennemsyn
# gennemset med
# er der lavet unittest?
# vælg repository
# ændringsomfang
# konsulentgennemgang med
# stadie
# indeholder tekster?
# klar til udgivelse
# giv besked til de andre udviklere
# link til jira
# noter mellem udviklere
# risikofiler ændret?
# testbeskrivelse til qa
# afhænger af følgende patches
# obs: patch må ikke skubbes til next endnu
# gennemse alle oplysninger og skub din patch til next. når patchen er skubbet til next, så må du trykke klar til udgivelse
# link til kontaktoplysninger
# lot nr. / batch nr.
# enhed
# beskrivelse
# vedhæft billed(er)
# vedhæft fil(er)
# begrund n/a
# valgte løsning
# leverandørens svar
# årsag
# send info til bruger(e)
# angiv hvorfor korrigerende handling(er) ikke er påkrævet
# dato for reklamation
# angiv årsag
# opfølgning udført d.
